# %% [markdown]
# # Problem Set 3

# %% [markdown]
# # Question 1
#
# ## Occupations
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from this address.
#
# Step 3. Assign it to a variable called users
#
# Step 4. Discover what is the mean age per occupation
#
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
#
# Step 6. For each occupation, calculate the minimum and maximum ages
#
# Step 7. For each combination of occupation and sex, calculate the mean age
#
# Step 8. For each occupation present the percentage of women and men

# %%
#Step 1
import pandas as pd

# %%
#Step 2 & 3 & 4
Users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', delimiter='|')
print('Mean age as per each Occupation:')
Users.groupby('occupation').age.mean()
# Out:
# Mean age as per each Occupation:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
#Step 5
print('Male Ratio Per Occupation In Most To The Least Form:')
Male_Occupation = Users.groupby(['occupation','gender']).gender.count()
Total = Users.groupby('gender').gender.count()
print((Male_Occupation/Total).sort_values(ascending=False).xs('M',level=1))
# Out:
# Male Ratio Per Occupation In Most To The Least Form:
# occupation
# student          0.202985
# other            0.102985
# educator         0.102985
# engineer         0.097015
# programmer       0.089552
# administrator    0.064179
# executive        0.043284
# scientist        0.041791
# technician       0.038806
# writer           0.038806
# librarian        0.032836
# marketing        0.023881
# entertainment    0.023881
# artist           0.022388
# retired          0.019403
# lawyer           0.014925
# salesman         0.013433
# doctor           0.010448
# healthcare       0.007463
# none             0.007463
# homemaker        0.001493
# Name: gender, dtype: float64

# %%
#Step 6
print('Minimum and Maximum of ages as per each Occupation:')
Users.groupby('occupation').agg({'age':['min','max']})
# Out:
# Minimum and Maximum of ages as per each Occupation:
#               age
#               min max
# occupation
# administrator  21  70
# artist         19  48
# doctor         28  64
# educator       23  63
# engineer       22  70
# entertainment  15  50
# executive      22  69
# healthcare     22  62
# homemaker      20  50
# lawyer         21  53
# librarian      23  69
# marketing      24  55
# none           11  55
# other          13  64
# programmer     20  63
# retired        51  73
# salesman       18  66
# scientist      23  55
# student         7  42
# technician     21  55
# writer         18  60

# %%
#Step 7
print('Mean age and sex based on occupation:')
Users.groupby(['occupation','gender']).age.mean()
# Out:
# Mean age and sex based on occupation:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# ...

# %%
#Step 8
Occupations = Users.groupby('occupation').gender.count()
Gender_Percentage_Per_Occupation = Users.groupby(['occupation','gender']).gender.count()
print('Percentage of women and men per occupation')
print(Gender_Percentage_Per_Occupation*100/Occupations)
# Out:
# Percentage of women and men per occupation
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
# ...

# %% [markdown]
# # Question 2
#
# ## Euro Teams
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from this address
#
# Step 3. Assign it to a variable called euro12
#
# Step 4. Select only the Goal column
#
# Step 5. How many team participated in the Euro2012?
#
# Step 6. What is the number of columns in the dataset?
#
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them
# to a dataframe called discipline
#
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
#
# Step 9. Calculate the mean Yellow Cards given per Team
#
# Step 10. Filter teams that scored more than 6 goalsStep 11. Select the teams
# that start with G
#
# Step 12. Select the first 7 columns
#
# Step 13. Select all columns except the last 3
#
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
#Step 1
import pandas as pd

# %%
#Step 2 & 3
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 4
print('Goal column:')
euro12['Goals']
# Out:
# Goal column:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#Step 5
print('Team participated in Euro2012:')
len(euro12.groupby('Team').groups)
# Out:
# Team participated in Euro2012:
# 16

# %%
#Step 6
print('No of columns in dataset:')
euro12.shape[1]
# Out:
# No of columns in dataset:
# 35

# %%
#Step 7
print('Discipline:')
discipline = euro12[['Team','Yellow Cards', 'Red Cards']]
discipline
# Out:
# Discipline:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#Step 8
discipline.sort_values(by=['Red Cards','Yellow Cards'],ascending= False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
#Step 9
print('The mean of Yellow Cards:')
euro12.groupby('Team').agg({'Yellow Cards': 'mean'})
# Out:
# The mean of Yellow Cards:
#                      Yellow Cards
# Team
# Croatia                       9.0
# Czech Republic                7.0
# Denmark                       4.0
# England                       5.0
# France                        6.0
# Germany                       4.0
# Greece                        9.0
# Italy                        16.0
# Netherlands                   5.0
# Poland                        7.0
# Portugal                     12.0
# Republic of Ireland           6.0
# Russia                        6.0
# Spain                        11.0
# Sweden                        7.0
# Ukraine                       5.0

# %%
#Step 10
print('Teams With More than 6 Goals:')
euro12[euro12.Goals>6]
# Out:
# Teams With More than 6 Goals:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# ...

# %%
#Step 11
print('Teams that start with letter G:')
euro12[euro12.Team.str.startswith('G')]
# Out:
# Teams that start with letter G:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# ...

# %%
#Step 12
print('The first seven columns:')
euro12.iloc[:,:7]
# Out:
# The first seven columns:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 13
euro12.iloc[:,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 14
print('Shooting Accuracy of England, Italt and Russia:')
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team','Shooting Accuracy']]
# Out:
# Shooting Accuracy of England, Italt and Russia:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question 3
#
# ## Housing
#
# Step 1. Import the necessary libraries
#
# Step 2. Create 3 differents Series, each of length 100, as follows:
#
# • The first a random number from 1 to 4
#
# • The second a random number from 1 to 3
#
# • The third a random number from 10,000 to 30,000
#
# Step 3. Create a DataFrame by joinning the Series by column
#
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
#
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
#
# Step 6. Ops it seems it is going only until index 99. Is it true?
#
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
#Step 1
import pandas as pd
import numpy as ny

# %%
#Step 2
series_1 = pd.Series(ny.random.randint(1,4,100))
series_2 = pd.Series(ny.random.randint(1,3,100))
series_3 = pd.Series(ny.random.randint(10000,30000,100))

# %%
#Step 3 
dataframe = pd.DataFrame({'1':series_1,'2':series_2,'3':series_3})
dataframe
# Out:
#     1  2      3
# 0   3  1  10810
# 1   1  2  12521
# 2   3  2  15300
# 3   3  2  12935
# 4   2  2  16530
# .. .. ..    ...
# 95  2  1  27020
# 96  2  1  15507
# 97  3  2  15600
# 98  1  2  22712
# 99  3  1  23170
#
# [100 rows x 3 columns]

# %%
#Step 4 
print('The name of columns:')
dataframe = pd.DataFrame({'bedrs':series_1, 'bathrs':series_2, 'price_sqr_meter':series_3})
dataframe
# Out:
# The name of columns:
#     bedrs  bathrs  price_sqr_meter
# 0       3       1            10810
# 1       1       2            12521
# 2       3       2            15300
# 3       3       2            12935
# 4       2       2            16530
# ..    ...     ...              ...
# 95      2       1            27020
# 96      2       1            15507
# 97      3       2            15600
# 98      1       2            22712
# 99      3       1            23170
#
# [100 rows x 3 columns]

# %%
#Step 5
print('Bigcolumn:')
bigcolumn = pd.concat([series_1,series_2,series_3])
bigcolumn
# Out:
# Bigcolumn:
# 0         3
# 1         1
# 2         3
# 3         3
# 4         2
#       ...
# 95    27020
# 96    15507
# 97    15600
# 98    22712
# 99    23170
# Length: 300, dtype: int32

# %%
#Step 6: Ops it seems it is going only until index 99. Is it true?
#Yes it is going till index 99.

# %%
#Step 7
print('Reindexing the DataFrame:')
bigcolumn.index = pd.RangeIndex(start=0, stop=300)
bigcolumn
# Out:
# Reindexing the DataFrame:
# 0          3
# 1          1
# 2          3
# 3          3
# 4          2
#        ...
# 295    27020
# 296    15507
# 297    15600
# 298    22712
# 299    23170
# Length: 300, dtype: int32

# %% [markdown]
# # Question 4
#
# ## Wind Statistics
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using a for loop or other looping construct.
#
# The data in 'wind.data' has the following format:
#
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL MAL
#
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04
#
# 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
#
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.71
#
# The first three columns are year, month, and day. The remaining 12 columns are
# average windspeeds in knots at 12 locations in Ireland on that day.
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from the attached file wind.txt
#
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper
# datetime index.
#
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it
# and apply it.
#
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be
# datetime64.
#
# Step 6. Compute how many values are missing for each location over the entire
# record.They should be ignored in all calculations below.
#
# Step 7. Compute how many non-missing values there are in total.
#
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and
# all the times.A single number for the entire dataset.
#
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean
# windspeeds and standard deviations of the windspeeds at each location over all the
# days. A different set of numbers for each location.
#
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean
# windspeed and standard deviations of the windspeeds across all the locations at each
# day.A different set of numbers for each day.
#
# Step 11. Find the average windspeed in January for each location.
# Treat January 1961 and January 1962 both as January.
#
# Step 12. Downsample the record to a yearly frequency for each location.
#
# Step 13. Downsample the record to a monthly frequency for each location.
#
# Step 14. Downsample the record to a weekly frequency for each location.
#
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the
# windspeeds across all locations for each week (assume that the first week starts on
# January 2 1961) for the first 52 weeks.

# %%
#Step 1 Import the necessary libraries
import pandas as pd
import numpy as ny
import datetime

# %%
#Step 2 Import the dataset from the attached file wind.txt 
#Step 3 Assign it to a variable called data and replace the first 3 columns by a proper datetime index.
data = pd.read_csv("wind.txt",sep="\s+",parse_dates = {'Datetime':['Yr','Mo','Dy']}) 
data
# Out:
#        Datetime    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# ...

# %%
#Step 5
print('Right dates:')
data.set_index(["Datetime"],inplace=True)
data
# Out:
# Right dates:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Datetime
# 2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# Datetime
# ...

# %%
#Step 6  Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below
print('The missing values:')
values = data.isnull().sum()
values
# Out:
# The missing values:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
#Step 7 Compute how many non-missing values there are in total.
print('Non-missing values:')
non_missing = data.notna().sum()
non_missing
# Out:
# Non-missing values:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
#Step 8 . Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
print('The mean windspeeds of all location:')
ws = data.mean().mean()
ws
# Out:
# The mean windspeeds of all location:
# 10.227982360836924

# %%
#Step 10 Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the 
#windspeeds across all the locations at each day. A different set of numbers for each day.

print('The Min, Max, Mean and Standard Deviation:')

day_stats = pd.DataFrame()
day_stats['Min']= data.min(axis=0)
day_stats['Max']= data.max(axis=0)
day_stats['Mean']= data.mean(axis=0)
day_stats['Standard Deviation']= data.std(axis=0)
day_stats
# Out:
# The Min, Max, Mean and Standard Deviation:
#       Min    Max       Mean  Standard Deviation
# RPT  0.67  35.80  12.362987            5.618413
# VAL  0.21  33.37  10.644314            5.267356
# ROS  1.50  33.84  11.660526            5.008450
# KIL  0.00  28.46   6.306468            3.605811
# SHA  0.13  37.54  10.455834            4.936125
# BIR  0.00  26.16   7.092254            3.968683
# DUB  0.00  30.37   9.797343            4.977555
# CLA  0.00  31.08   8.495053            4.499449
# MUL  0.00  25.88   8.493590            4.166872
# CLO  0.04  28.21   8.707332            4.503954
# BEL  0.13  42.38  13.121007            5.835037
# MAL  0.67  42.54  15.599079            6.699794

# %%
#Step 11 Find the average windspeed in January for each location. Treat January 1961 and January 1962 both as January.
print('The average windspeed in January:')
data.loc[data.index.month ==1].mean()
# Out:
# The average windspeed in January:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
#Step 12 Downsample the record to a yearly frequency for each location.
print('The record to a yearly frequency:')
year= data.asfreq('Y') 
year
# Out:
# The record to a yearly frequency:
#               RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA    MUL  \
# Datetime
# 1972-12-31  13.83  14.46  15.87  9.75   8.71  11.00  10.67  11.54  11.50
# 1973-12-31  10.67  10.04   6.87  1.46   6.96   5.75   3.83   6.21   4.75
# 1974-12-31  16.04  16.29  15.21  8.42  13.67   9.75  15.25  16.13  15.04
# 1975-12-31  15.59  12.33  13.42  2.37   4.08   1.17   7.08   4.25   5.91
# 1976-12-31   8.67   8.83   9.38  3.67   5.37   4.58   7.92   1.79   4.46
# ...           ...    ...    ...   ...    ...    ...    ...    ...    ...
# 2067-12-31  16.88  13.75  11.34  9.08  13.54   7.71  11.75  11.83  11.83
# 2068-12-31   9.13   2.13   7.38  2.50   4.04   0.50   6.83   2.54   3.54
# 2069-12-31  14.42  13.83  27.71  7.08  12.08  10.00  14.58  11.00  12.54
# 2070-12-31   8.38   0.37   9.59  2.62   1.75   0.08   4.83   2.13   2.54
# 2071-12-31  14.88  10.50  26.08  8.46  13.50  10.04  21.04  10.25  13.54
#
#               CLO    BEL    MAL
# Datetime
# ...

# %%
#Step 13  Downsample the record to a monthly frequency for each location.
print('The record to a monthly frequency')
monthly= data.asfreq('M') 
monthly
# Out:
# The record to a monthly frequency
#               RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA    MUL  \
# Datetime
# 1972-01-31  22.50  22.29  19.08  8.00  20.96  14.50  12.50  14.33  11.50
# 1972-02-29  16.13  15.12  12.46  7.46  14.67   9.62   8.58  10.92  10.37
# 1972-03-31  12.21  11.04  12.08  6.13  11.17   7.04   8.54   8.96   9.17
# 1972-04-30  13.62  12.87  15.37  6.29  10.83   5.58  11.50   8.58   8.58
# 1972-05-31  10.04   6.92   8.46  5.63   9.92   5.83   7.96   7.21   9.33
# ...           ...    ...    ...   ...    ...    ...    ...    ...    ...
# 2071-08-31  15.12  13.96  13.33  7.21  17.37  11.34  14.67  12.12  13.54
# 2071-09-30  10.29  13.04   9.21  4.38  10.00   7.83   7.41   5.66   7.12
# 2071-10-31   8.63   7.87   9.29  2.92   8.83   7.00   6.21   8.21   6.21
# 2071-11-30  16.29  16.08   8.33  4.00  11.34   5.79   9.08   5.83   8.08
# 2071-12-31  14.88  10.50  26.08  8.46  13.50  10.04  21.04  10.25  13.54
#
#               CLO    BEL    MAL
# Datetime
# ...

# %%
#Step 14 Downsample the record to a weekly frequency for each location.
print('The record to a weekly frequency')
weekly= data.asfreq('W') 
weekly
# Out:
# The record to a weekly frequency
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Datetime
# 1972-01-02   8.96   1.46  12.00   4.50   3.21   0.83   6.04   0.67   3.79
# 1972-01-09  11.00   7.41   8.50   3.04   7.54   4.29   5.25   3.37   5.79
# 1972-01-16  23.67  20.62  20.17   8.79  16.83  12.75  16.58  12.50  12.33
# 1972-01-23  20.41  17.00  18.46   8.92  13.92  11.29  13.00  12.08  12.46
# 1972-01-30  11.25  10.13  10.34   2.37   8.08   2.58   6.92   4.29   5.00
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2071-11-29  11.67  10.79  12.04   3.21  11.79   8.00   7.83   7.62   7.67
# 2071-12-06   5.29   4.04   4.46   1.04   4.67   2.79   5.96   3.75   3.75
# 2071-12-13  15.79  10.83  13.92   6.29  10.83   8.38  12.08   6.58   9.75
# 2071-12-20  21.84  21.17  20.08  10.63  20.38  16.46  21.92  17.54  18.71
# 2071-12-27   8.75   6.13   9.04   3.13   7.00   7.41  13.13  12.96  11.12
#
#               CLO    BEL    MAL
# ...

# %%
#Step 15 Calculate the min, max and mean windspeeds and standard deviations of the 
windspeeds across all locations for each week (assume that the first week starts on 
January 2 1961) for the first 52 weeks.

# %% [markdown]
# # Question 5
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from this address.
#
# Step 3. Assign it to a variable called chipo.
#
# Step 4. See the first 10 entries
#
# Step 5. What is the number of observations in the dataset?
#
# Step 6. What is the number of columns in the dataset?
#
# Step 7. Print the name of all the columns.
#
# Step 8. How is the dataset indexed?
#
# Step 9. Which was the most-ordered item?
#
# Step 10. For the most-ordered item, how many items were ordered?
#
# Step 11. What was the most ordered item in the choice_description column?
#
# Step 12. How many items were orderd in total?
#
# Step 13.
#
# • Turn the item price into a float
#
# • Check the item price type
#
# • Create a lambda function and change the type of item price
#
# • Check the item price type
#
# Step 14. How much was the revenue for the period in the dataset?
#
# Step 15. How many orders were made in the period?
#
# Step 16. What is the average revenue amount per order?
#
# Step 17. How many different items are sold?

# %%
#Step 1
import pandas as jp

# %%
#Step 2 & 3
chipo = jp.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#Step 4
print('The first 10 entries are:')
first=chipo.head(10)
first
# Out:
# The first 10 entries are:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#Step 5
print('Number of observation:')
observation = chipo.shape[0]
observation
# Out:
# Number of observation:
# 4622

# %%
#Step 6
print('Number of columns:')
columns = chipo.shape[1]
columns
# Out:
# Number of columns:
# 5

# %%
#Step 7
print('Name of all the columns:')
names = chipo.columns
names
# Out:
# Name of all the columns:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#Step 8
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#Step 9
print('Most ordered item:')
ordered = chipo[chipo.quantity==chipo.quantity.max()].item_name
ordered
# Out:
# Most ordered item:
# 3598    Chips and Fresh Tomato Salsa
# Name: item_name, dtype: object

# %%
#Step 10 
print('Number of items ordered most:')
ordered = chipo[chipo.quantity==chipo.quantity.max()].quantity 
ordered
# Out:
# Number of items ordered most:
# 3598    15
# Name: quantity, dtype: int64

# %%
#Step 11
print('The choice description column most ordered item is:')
chipo.choice_description.value_counts().head(1)
# Out:
# The choice description column most ordered item is:
# [Diet Coke]    134
# Name: choice_description, dtype: int64

# %%
#Step 12
print('Total items ordered:')
total = chipo.quantity.sum()
total
# Out:
# Total items ordered:
# 4972

# %%
#Step 13
• Turn the item price into a float
• Check the item price type
• Create a lambda function and change the type of item price
• Check the item price type

# %%
#Step 14
print('The revenue for the period')
re = (chipo.item_price).sum() 
re
# Out:
# The revenue for the period
# ...

# %%
#Step 15
print('Total orders made:')
orders = chipo['order_id'].sum()
orders
# Out:
# Total orders made:
# 4285772

# %%
#Step 16 What is the average revenue amount per order?

# %%
#Step 17
print('Number of different item sold:')
chipo.item_name.nunique()
# Out:
# Number of different item sold:
# 50

# %% [markdown]
# # Question 6
#
# Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import pandas as jp
import matplotlib.pyplot as mp
marriage = jp.read_csv(r"C:\Users\ASUS\Downloads\Problem_Set_3\us-marriages-divorces-1867-2014.csv")
marriage.plot(x='Year', y=['Marriages_per_1000', 'Divorces_per_1000'])
mp.title('Marriages and Divorces per capita in the U.S.')
mp.xlabel('Years')
mp.ylabel('Marriages and Divorces per Capita (US)')
mp.show()

# %% [markdown]
# # Question 7
#
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
import matplotlib.pyplot as mp
import numpy as ny
mp.figure(figsize=[20, 10])
marriages = [709000, 1667000, 2315000]
divorces = [56000, 385000, 944000]
z = ny.arange(len(marriages))
mp.bar(z, marriages, color = 'purple', width = 0.20)
mp.bar(z + 0.20, divorces, color = 'blue', width = 0.20)
mp.legend(['Marriage', 'Divorce'])
mp.xticks([i + 0.25 for i in range(3)], ['1900', '1950', '2000'])
mp.title("Comparing the number of marriages and divorces")
mp.xlabel('Years')
mp.ylabel('Marriages and Divorces')
mp.show()

# %% [markdown]
# # Question 8
#
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as mp
actor = pd.read_csv(r"C:\Users\ASUS\Downloads\Problem_Set_3\actor_kill_counts.csv")
actor.plot.barh(x='Actor', y='Count')
mp.title("Deadlist actors in Hollywood")
mp.xlabel('Kills Count')
mp.ylabel('Actors')
mp.grid(axis='x', linestyle = '--') 
mp.show()

# %% [markdown]
# # Question 9
#
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
#
# Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
import pandas as pd
import matplotlib.pyplot as mp
regins = pd.read_csv(r'C:\Users\ASUS\Downloads\Problem_Set_3\roman-emperor-reigns.csv')
death = regins[regins['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]
print(death) 
roman = death['Emperor']
cause = death['Cause_of_Death']
mp.pie(range(len(cause)),labels = roman, autopct='%1.2f%%', startangle= 40, radius=0.045 * 100, rotatelabels = 300)
figure = mp.figure(figsize=[10, 5])
mp.show()
# Out:
#                Emperor  Length_of_Reign         Cause_of_Death
# 0             Augustus            40.58  Possibly assassinated
# 1             Tiberius            22.50  Possibly assassinated
# 2             Caligula             4.83           Assassinated
# 3             Claudius            13.75  Possibly assassinated
# 5                Galba             0.58           Assassinated
# 7            Vitellius             0.67           Assassinated
# 10            Domitian            15.00           Assassinated
# 17            Commodus            15.00           Assassinated
# 18            Pertinax             0.25           Assassinated
# 21           Caracalla            19.00           Assassinated
# 22                Geta             3.00           Assassinated
# 24          Elagabalus             3.75           Assassinated
# 25   Severus Alexander            13.00           Assassinated
# 26         Maximinus I             3.25           Assassinated
# ...

# %% [markdown]
# # Question 10
#
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
#
# Don't forget to label your axes!
#
# Color each dot according to its year.

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as mp
revenue = pd.read_csv(r"C:\Users\ASUS\Downloads\Problem_Set_3\arcade-revenue-vs-cs-doctorates.csv")
sb.scatterplot(hue='Year', x='Total Arcade Revenue (billions)', y='Computer Science Doctorates Awarded (US)',data=revenue)
# Out:
# <AxesSubplot:xlabel='Total Arcade Revenue (billions)', ylabel='Computer Science Doctorates Awarded (US)'>
